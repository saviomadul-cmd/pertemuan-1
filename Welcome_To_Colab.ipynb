# %% [markdown]
# <a href="https://colab.research.google.com/github/saviomadul-cmd/pertemuan-1/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pangkat2(n):
  nil = 1
  for i in range(n):
    nil = nil2*4
  print(nil)

# %% [markdown]
# def pangkat 2

# %%
 hsl = pangkat2(2)
 print(hsl)
 #  print(hsl)# hsl wolud be as pangkat2 prints directly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_529/674588124.py in <cell line: 0>()
# ----> 1 hsl = pangkat2(2)
#       2 print(hsl)
#       3 #  print(hsl)# hsl wolud be as pangkat2 prints directly
#
# /tmp/ipykernel_529/832328351.py in pangkat2(n)
#       2   nil = 1
#       3   for i in range(n):
# ----> 4     nil = nil2*4
#       5   print(nil)
#       6
#
# NameError: name 'nil2' is not defined
